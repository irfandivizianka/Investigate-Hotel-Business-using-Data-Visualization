# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Membaca Dataset**

# %%
df = pd.read_csv('hotel_bookings_data.csv')

# %% [markdown]
# ***TASK 1***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  city                            118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  booking_changes                 119390 non-null  int64
#  20  deposit_type                    119390 non-null  object
#  21  agent                           103050 non-null  float64
#  22  company                         6797 non-null    float64
#  23  days_in_waiting_list            119390 non-null  int64
#  24  customer_type                   119390 non-null  object
#  25  adr                             119390 non-null  float64
#  26  required_car_parking_spaces     119390 non-null  int64
#  27  total_of_special_requests       119390 non-null  int64
#  28  reservation_status              119390 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 26.4+ MB

# %%
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 92790     City Hotel            0         56               2018
# 23358   Resort Hotel            0         92               2018
# 81453     City Hotel            0          6               2017
# 27493   Resort Hotel            0         40               2018
# 107224    City Hotel            0         38               2019
# 32270   Resort Hotel            0          0               2019
# 79310     City Hotel            0         43               2017
# 73309     City Hotel            1        104               2019
# 65822     City Hotel            1        248               2019
# 86562     City Hotel            0         66               2018
#
#        arrival_date_month  arrival_date_week_number  \
# 92790           September                        29
# 23358                June                        17
# 81453            February                        50
# 27493             October                        36
# 107224                May                        10
# 32270               March                         3
# 79310            December                        43
# 73309             October                        33
# 65822                June                        15
# 86562                June                        15
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 92790                          11                        1
# 23358                          21                        0
# 81453                          10                        0
# 27493                          31                        0
# 107224                          7                        0
# 32270                          19                        0
# 79310                          23                        0
# 73309                          18                        1
# 65822                           9                        2
# 86562                           4                        1
#
#         stays_in_weekdays_nights  adults  ...  booking_changes  deposit_type  \
# 92790                          0       2  ...                0    No Deposit
# 23358                          2       1  ...                1    No Deposit
# 81453                          2       1  ...                0    No Deposit
# 27493                          0       3  ...                0    No Deposit
# 107224                         3       2  ...                0    No Deposit
# 32270                          1       2  ...                0    No Deposit
# 79310                          1       2  ...                0    No Deposit
# 73309                          2       2  ...                0    No Deposit
# 65822                          0       2  ...                0    No Deposit
# 86562                          1       2  ...                0    No Deposit
#
#         agent company days_in_waiting_list customer_type     adr  \
# 92790     7.0     NaN                    0      Personal   88.01
# 23358   240.0     NaN                    0      Personal   73.00
# 81453     6.0     NaN                    0        Family    0.00
# 27493   241.0     NaN                    0      Personal    0.00
# 107224    9.0     NaN                    0      Personal   88.00
# 32270     NaN     NaN                    0      Personal   77.00
# 79310     2.0     NaN                    0        Family    0.00
# 73309     9.0     NaN                    0      Personal  125.00
# 65822    58.0     NaN                    0        Family   80.00
# 86562     9.0     NaN                    0        Family  105.30
#
#         required_car_parking_spaces  total_of_special_requests  \
# 92790                             0                          0
# 23358                             0                          2
# 81453                             0                          0
# 27493                             0                          1
# 107224                            0                          1
# 32270                             1                          0
# 79310                             0                          0
# 73309                             0                          1
# 65822                             0                          1
# 86562                             0                          1
#
#         reservation_status
# 92790            Check-Out
# 23358            Check-Out
# 81453            Check-Out
# 27493            Check-Out
# 107224           Check-Out
# 32270            Check-Out
# 79310            Check-Out
# 73309             Canceled
# 65822             Canceled
# 86562            Check-Out
#
# [10 rows x 29 columns]

# %%
#check duplicated data
df.duplicated().sum()
# Out:
# 33261

# %%
#copy data

df2 = df.copy()

# %% [markdown]
# **Data Processing**

# %%
# Cek total data yang kosong
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_weekdays_nights               0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# city                                 488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# dtype: int64

# %% [markdown]
# Kesimpulan Sementara :
#
# 1. Terdapat 4 kolom yang memiliki missing value , diantaranya adalah city, children, agent, company.
# 2. Mengisi nilai kolom diatas menggunakan nilai 0 pada kolom ( children, agent, company ) dan unknown untuk kolom city, sehingga tidak ada nilai missing value.

# %%
#drop dan cek kembali data yang duplikat
df.drop_duplicates(keep='first', inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
#cek data setelah drop data yang duplikat
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86125 non-null  float64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            85679 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           74188 non-null  float64
#  22  company                         5110 non-null   float64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 19.7+ MB

# %%
#cek data yang kosong setelah melakukan drop data yang duplikat 

df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_weekdays_nights              0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# city                                450
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# booking_changes                       0
# deposit_type                          0
# agent                             11941
# company                           81019
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# dtype: int64

# %%
#Mengisi kolom yang memiliki missing value menggunakan 0 untuk kolom bertipe data numerik dan unknown untuk kolom bertipe data object

df['children'] = df['children'].fillna(0)
df['city'] = df['city'].fillna('unknown')
df['company'] = df['company'].fillna(0)
df['agent'] = df['agent'].fillna(0)

# %% [markdown]
# **Cek kolom yang sudah di isi dengan nilai 0 dan unknown**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86129 non-null  float64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            86129 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           86129 non-null  float64
#  22  company                         86129 non-null  float64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 19.7+ MB

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_weekdays_nights          0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# city                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# dtype: int64

# %% [markdown]
# Kesmipulan :
#
# 1. Kolom yang memiliki nilai null sudah berhasil di isi dengan nilai 0 sehingga tidak ada lagi kolom yang kosong.

# %%
#mengubah kolom bertipe data float menjadi numerik
df['children'] = df['children'].astype('int64')
df['agent'] = df['agent'].astype('int64')
df['company'] = df['company'].astype('int64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86129 non-null  int64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            86129 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           86129 non-null  int64
#  22  company                         86129 non-null  int64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(1), int64(19), object(9)
# memory usage: 19.7+ MB

# %% [markdown]
# **Mengatasi data yang tidak sesuai**

# %%
# membagi data berdasarkan type datanya
category = df.select_dtypes(include='object')
numerical = df.select_dtypes(exclude='object')

numerical_cols = numerical.columns.to_list()
category_cols = category.columns.to_list()

print("Data numerik: ", numerical_cols)
print("Data category: ", category_cols)
# Out:
# Data numerik:  ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_weekdays_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
# Data category:  ['hotel', 'arrival_date_month', 'meal', 'city', 'market_segment', 'distribution_channel', 'deposit_type', 'customer_type', 'reservation_status']

# %%
df[numerical_cols].describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  86129.000000  86129.000000       86129.000000
# mean       0.275587     79.246224        2018.215467
# std        0.446812     85.498774           0.683948
# min        0.000000      0.000000        2017.000000
# 25%        0.000000     11.000000        2018.000000
# 50%        0.000000     49.000000        2018.000000
# 75%        1.000000    124.000000        2019.000000
# max        1.000000    737.000000        2019.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              86129.000000               86129.000000
# mean                  26.796433                  15.806511
# std                   13.675130                   8.840436
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_weekdays_nights        adults  \
# count             86129.000000              86129.000000  86129.000000
# mean                  1.009753                  2.633225      1.878554
# std                   1.033402                  2.058316      0.627558
# min                   0.000000                  0.000000      0.000000
# 25%                   0.000000                  1.000000      2.000000
# 50%                   1.000000                  2.000000      2.000000
# 75%                   2.000000                  4.000000      2.000000
# max                  19.000000                 50.000000     55.000000
#
#            children        babies  is_repeated_guest  previous_cancellations  \
# count  86129.000000  86129.000000       86129.000000            86129.000000
# mean       0.140278      0.010984           0.039499                0.030570
# std        0.458337      0.114421           0.194780                0.371465
# min        0.000000      0.000000           0.000000                0.000000
# 25%        0.000000      0.000000           0.000000                0.000000
# 50%        0.000000      0.000000           0.000000                0.000000
# 75%        0.000000      0.000000           0.000000                0.000000
# max       10.000000     10.000000           1.000000               26.000000
#
#        previous_bookings_not_canceled  booking_changes         agent  \
# count                    86129.000000     86129.000000  86129.000000
# mean                         0.186569         0.271987     81.199166
# std                          1.744405         0.729529    109.964005
# min                          0.000000         0.000000      0.000000
# 25%                          0.000000         0.000000      9.000000
# 50%                          0.000000         0.000000      9.000000
# 75%                          0.000000         0.000000    240.000000
# max                         72.000000        21.000000    535.000000
#
#             company  days_in_waiting_list           adr  \
# count  86129.000000          86129.000000  86129.000000
# mean      10.800021              0.645114    106.634109
# std       53.484435              9.282699     55.175319
# min        0.000000              0.000000     -6.380000
# 25%        0.000000              0.000000     72.250000
# 50%        0.000000              0.000000     98.750000
# 75%        0.000000              0.000000    134.510000
# max      543.000000            391.000000   5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                 86129.000000               86129.000000
# mean                      0.085233                   0.705059
# std                       0.283070                   0.833525
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   1.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %%
df[category_cols].describe()
# Out:
#              hotel arrival_date_month       meal           city  \
# count        86129              86129      86129          86129
# unique           2                 12          5            178
# top     City Hotel            October  Breakfast  Kota Denpasar
# freq         52575              11150      67088          26903
#
#        market_segment distribution_channel deposit_type customer_type  \
# count           86129                86129        86129         86129
# unique              8                    5            3             4
# top         Online TA                TA/TO   No Deposit      Personal
# freq            51393                68141        85024         71648
#
#        reservation_status
# count               86129
# unique                  3
# top             Check-Out
# freq                62393

# %%
pd.unique(df['meal'])
# Out:
# array(['Breakfast', 'Full Board', 'Dinner', 'No Meal', 'Undefined'],
#       dtype=object)

# %%
len(df[df['meal'] == 'Undefined'])
# Out:
# 454

# %%
df.shape
# Out:
# (86129, 29)

# %%
# drop nilai "undefined" ganti dengan No Meal pada kolom meal
df["meal"].replace("Undefined", "No Meal", inplace=True)

# %%
pd.unique(df['meal'])
df['meal'].value_counts()
# Out:
# Breakfast     67088
# No Meal        9896
# Dinner         8798
# Full Board      347
# Name: meal, dtype: int64

# %%
df.shape
# Out:
# (86129, 29)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  adults  ...  \
# 0                        0                         0       2  ...
# 1                        0                         0       2  ...
# 2                        0                         1       1  ...
# 3                        0                         1       1  ...
# 4                        0                         2       2  ...
#
#    booking_changes  deposit_type agent company days_in_waiting_list  \
# 0                3    No Deposit     0       0                    0
# 1                4    No Deposit     0       0                    0
# 2                0    No Deposit     0       0                    0
# 3                0    No Deposit   304       0                    0
# 4                0    No Deposit   240       0                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0      Personal   0.0                            0                          0
# 1      Personal   0.0                            0                          0
# 2      Personal  75.0                            0                          0
# 3      Personal  75.0                            0                          0
# 4      Personal  98.0                            0                          1
#
#    reservation_status
# 0           Check-Out
# 1           Check-Out
# 2           Check-Out
# 3           Check-Out
# 4           Check-Out
#
# [5 rows x 29 columns]

# %%
# Menghapus data sebelumnya dengan data 0 guest dan 0 night 
# Membuat kolom baru dengan nama  'total_guests' dari kombinasi kolom 'adults', 'children', 'babies' columns
df['total_guests'] = df['adults'] + df['children'] + df['babies']
print('Data with 0 guest: {0} out of {1} all data'.format(df[df['total_guests'] == 0].shape[0], df.shape[0]))

# membuat kolom 'stay_duration' dari kombinasi kolom 'stays_in_weekend_nights' dan 'stays_in_weekdays_nights'
df['stay_duration'] = df['stays_in_weekend_nights'] + df['stays_in_weekdays_nights']
print('Data with 0 night: {0} out of {1} all data'.format(df[df['stay_duration'] == 0].shape[0], df.shape[0]))


df_clean = df[(df['total_guests'] > 0) & (df['stay_duration'] > 0)].copy()

print('sebelum pre-processing:', df.shape[0])
print('setelah pre-processing:', df_clean.shape[0])
# Out:
# Data with 0 guest: 165 out of 86129 all data
# Data with 0 night: 645 out of 86129 all data
# sebelum pre-processing: 86129
# setelah pre-processing: 85378

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85378 entries, 2 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85378 non-null  object
#  1   is_canceled                     85378 non-null  int64
#  2   lead_time                       85378 non-null  int64
#  3   arrival_date_year               85378 non-null  int64
#  4   arrival_date_month              85378 non-null  object
#  5   arrival_date_week_number        85378 non-null  int64
#  6   arrival_date_day_of_month       85378 non-null  int64
#  7   stays_in_weekend_nights         85378 non-null  int64
#  8   stays_in_weekdays_nights        85378 non-null  int64
#  9   adults                          85378 non-null  int64
#  10  children                        85378 non-null  int64
#  11  babies                          85378 non-null  int64
#  12  meal                            85378 non-null  object
#  13  city                            85378 non-null  object
#  14  market_segment                  85378 non-null  object
#  15  distribution_channel            85378 non-null  object
#  16  is_repeated_guest               85378 non-null  int64
#  17  previous_cancellations          85378 non-null  int64
#  18  previous_bookings_not_canceled  85378 non-null  int64
#  19  booking_changes                 85378 non-null  int64
#  20  deposit_type                    85378 non-null  object
#  21  agent                           85378 non-null  int64
#  22  company                         85378 non-null  int64
#  23  days_in_waiting_list            85378 non-null  int64
#  24  customer_type                   85378 non-null  object
#  25  adr                             85378 non-null  float64
#  26  required_car_parking_spaces     85378 non-null  int64
#  27  total_of_special_requests       85378 non-null  int64
#  28  reservation_status              85378 non-null  object
#  29  total_guests                    85378 non-null  int64
#  30  stay_duration                   85378 non-null  int64
# dtypes: float64(1), int64(21), object(9)
# memory usage: 20.8+ MB

# %%
#simpan dataframe baru ke csv

df_clean.to_csv('Data_Hotel_Cleaning.csv', index=False)

# %% [markdown]
# **TASK 2**
#
# **Monthly Hotel Booking Analysis Based on Hotel Type**

# %%
df2 = df_clean.copy()

# %%
df2_mh = df2.groupby(['hotel','arrival_date_month'])['arrival_date_year'].agg(['nunique','count']).reset_index()
df2_mh.columns = ['hotel_type','arrival_month','unique_year','total_booking']
df2_mh
# Out:
#       hotel_type arrival_month  unique_year  total_booking
# 0     City Hotel         April            2           3514
# 1     City Hotel        August            2           4908
# 2     City Hotel      December            2           4009
# 3     City Hotel      February            2           2952
# 4     City Hotel       January            2           2849
# 5     City Hotel          July            2           5321
# 6     City Hotel          June            2           5017
# 7     City Hotel         March            2           2674
# 8     City Hotel           May            2           4777
# 9     City Hotel      November            2           4040
# 10    City Hotel       October            3           6473
# 11    City Hotel     September            3           5657
# 12  Resort Hotel         April            2           2453
# 13  Resort Hotel        August            2           2705
# 14  Resort Hotel      December            2           2618
# 15  Resort Hotel      February            2           2044
# 16  Resort Hotel       January            2           1995
# 17  Resort Hotel          July            2           2863
# 18  Resort Hotel          June            2           2756
# 19  Resort Hotel         March            2           1904
# 20  Resort Hotel           May            2           2585
# 21  Resort Hotel      November            2           2386
# 22  Resort Hotel       October            3           4615
# 23  Resort Hotel     September            3           4263

# %%
# Kelkulasi rata rata oder hotel perbulan selama beberapa tahun 
df2_mh['Average_Booking'] = round(df2_mh['total_booking']/df2_mh['unique_year'])
df2_mh
# Out:
#       hotel_type arrival_month  unique_year  total_booking  Average_Booking
# 0     City Hotel         April            2           3514           1757.0
# 1     City Hotel        August            2           4908           2454.0
# 2     City Hotel      December            2           4009           2004.0
# 3     City Hotel      February            2           2952           1476.0
# 4     City Hotel       January            2           2849           1424.0
# 5     City Hotel          July            2           5321           2660.0
# 6     City Hotel          June            2           5017           2508.0
# 7     City Hotel         March            2           2674           1337.0
# 8     City Hotel           May            2           4777           2388.0
# 9     City Hotel      November            2           4040           2020.0
# 10    City Hotel       October            3           6473           2158.0
# 11    City Hotel     September            3           5657           1886.0
# 12  Resort Hotel         April            2           2453           1226.0
# 13  Resort Hotel        August            2           2705           1352.0
# 14  Resort Hotel      December            2           2618           1309.0
# 15  Resort Hotel      February            2           2044           1022.0
# 16  Resort Hotel       January            2           1995            998.0
# 17  Resort Hotel          July            2           2863           1432.0
# 18  Resort Hotel          June            2           2756           1378.0
# 19  Resort Hotel         March            2           1904            952.0
# 20  Resort Hotel           May            2           2585           1292.0
# 21  Resort Hotel      November            2           2386           1193.0
# 22  Resort Hotel       October            3           4615           1538.0
# 23  Resort Hotel     September            3           4263           1421.0

# %%
order_months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2_mh['month'] = df2_mh['arrival_month'].str[:3]
df2_mh['month'] = pd.Categorical(df2_mh['month'], categories=order_months, ordered=True)

df2_mh
# Out:
#       hotel_type arrival_month  unique_year  total_booking  Average_Booking  \
# 0     City Hotel         April            2           3514           1757.0
# 1     City Hotel        August            2           4908           2454.0
# 2     City Hotel      December            2           4009           2004.0
# 3     City Hotel      February            2           2952           1476.0
# 4     City Hotel       January            2           2849           1424.0
# 5     City Hotel          July            2           5321           2660.0
# 6     City Hotel          June            2           5017           2508.0
# 7     City Hotel         March            2           2674           1337.0
# 8     City Hotel           May            2           4777           2388.0
# 9     City Hotel      November            2           4040           2020.0
# 10    City Hotel       October            3           6473           2158.0
# 11    City Hotel     September            3           5657           1886.0
# 12  Resort Hotel         April            2           2453           1226.0
# 13  Resort Hotel        August            2           2705           1352.0
# 14  Resort Hotel      December            2           2618           1309.0
# 15  Resort Hotel      February            2           2044           1022.0
# 16  Resort Hotel       January            2           1995            998.0
# 17  Resort Hotel          July            2           2863           1432.0
# 18  Resort Hotel          June            2           2756           1378.0
# 19  Resort Hotel         March            2           1904            952.0
# 20  Resort Hotel           May            2           2585           1292.0
# 21  Resort Hotel      November            2           2386           1193.0
# 22  Resort Hotel       October            3           4615           1538.0
# 23  Resort Hotel     September            3           4263           1421.0
#
#    month
# 0    Apr
# 1    Aug
# 2    Dec
# 3    Feb
# 4    Jan
# 5    Jul
# 6    Jun
# 7    Mar
# 8    May
# 9    Nov
# 10   Oct
# 11   Sep
# 12   Apr
# 13   Aug
# 14   Dec
# 15   Feb
# 16   Jan
# 17   Jul
# 18   Jun
# 19   Mar
# 20   May
# 21   Nov
# 22   Oct
# 23   Sep

# %%
# visualisasi rata rata booking order kedua hotel tiap bulannya 
plt.figure(figsize=(15,10))
sns.lineplot(x='month', y='Average_Booking', hue='hotel_type',
             size='hotel_type', sizes=(5, 5), data=df2_mh, palette= ['blue', 'red'])

plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(alpha=0.3)
plt.legend(title='Hotel Type :', title_fontsize=14, prop={'size':12}, fontsize='x-large')

plt.xlabel('Arrival Month', fontsize=15)
plt.ylabel('Average Number of Booking', fontsize=15)
plt.ylim(0,4800)

plt.text(x=1.2, y=5300, s='Comparison Number Booking of Both Hotel', fontsize=26, fontweight='bold')
plt.text(x=1.2, y=5100, s='City hotel has decreased guest in August and September,', fontsize=22)
plt.text(x=0.5, y=4900, s='Both hotels have less customer during not holiday periode at (Jan-Mar)', fontsize=22)

plt.axvline(4, ls='--', color='green')
plt.axvline(6, ls='--', color='green')
plt.stackplot(np.arange(4,7,1),[[4800]], color='yellow', alpha=0.3)
plt.text(x=4.7, y=4400, s='Holiday\nSeason', fontsize=16, color='green')

plt.axvline(9, ls='--', color='green')
plt.axvline(11, ls='--', color='green')
plt.stackplot(np.arange(9,12,1),[[4800]], color='yellow', alpha=0.3)
plt.text(x=9.7, y=4400, s='Holiday\nSeason', fontsize=16, color='green')

plt.tight_layout()
